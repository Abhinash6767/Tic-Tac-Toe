# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhinash6767/Tic-Tac-Toe/blob/master/StringFormat1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
password = 'password'
len(password)

s = "hello world"
s[5:]
s[:5]
s[:] = print(s)
s[:-1]
s[:len(s) -1]
# s[2:1:4] //[start: stop: step]
s[2:8:4]
# s[::2] // Skip alternate
# s[::-1] // Reverse a string
s*2
s.upper()
s.lower()
l = s.split()
len(l)
'hello there: {}'.format(10)
x = 'Khan'
y = 'Delhi'
print("hi my name is %s and from %s" %(x,y))
# print('he said his name was %s' %'Fred') //he said his name was Fred
# print('he said his name was %r' %'Fred') //he said his name was 'Fred'
# %s and %r converts any python object to a string. %t inserts a tab into a string.

# %s operator converts whatever it sees into a string, including integers and floats. The %d operator converts number to integers first, without rounding.
# print("I wrote %s programs today" %3.76) //I wrote 3.76 programs today (Forces string values)
# print("I wrote %d programs today" %3.76) //I wrote 3 programs today (Forces Integer values)
# print("Floating point number: %10.2f" %(13.46868)) //Floating point number:      13.47

# print('The {1} {2} {0}'.format('fox','brown','quick')) //The brown quick fox
# print('First Object: {a}, Second Object: {b}, Third Object: {c}'.format(a=1, b='Two', c=12.3)) //First Object: 1, Second Object: Two, Third Object: 12.3
# print('A %s saved is a %s earned.' %('penny', 'penny')) //A penny saved is a penny earned.
# print('A {p} saved is a {p} earned'.format(p='penny')) //A penny saved is a penny earned

# print('{0:8} | {1:9} | {2:9}'.format('Fruit', 'Quantity', 'Price')); # {0:8} -> 8 chars wide, {1:9} -> 9 chars wide
# print('{0:8} | {1:9} | {2:7}'.format('Apple', 10, 120));
# print('{0:8} | {1:9} | {2:7}'.format('Orange', 14, 50));

# print('{0:>8} | {1:<9} | {2:^7}'.format('Fruit', 'Quantity', 'Price')); # <, >, ^ to set left, right and center alignment
# print('{0:>8} | {1:<9} | {2:^7}'.format('Apple', 10, 'abc'));
# print('{0:>8} | {1:<9} | {2:^7}'.format('Orange', 14, 50));

# print('This is my ten-character two-decimal number: %10.2f' %17.71) # 10 = Total field width, .2 = 2 digits after decimal, f=float - This is my ten-character two-decimal number:      17.71
# print('This is my ten-character two-decimal number: {0:010.2f}'.format(17.71)) #This is my ten-character two-decimal number: 0000017.71

# num = 680.234567
# print('My 10 character, four decimal number is: {0:10.4f}'.format(num)) My 10 character, four decimal number is:   680.2346
# print(f'My 10 character, four decimal number is: {num:{10}.{6}}') #My 10 character, four decimal number is:    680.235

# %%
password = 'password'
len(password)

s = "hello world I am new here"
s[7:]
# s[:7]
s[:-1]
# s*2
num = 23.45
print('My 10 character, four decimal number is: {0:10.4f}'.format(num))
print(f'My 10 character, four decimal number is: {num: 010.2f}')
# Out:
# My 10 character, four decimal number is:    23.4500
# My 10 character, four decimal number is:  000023.45
