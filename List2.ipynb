# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhinash6767/Tic-Tac-Toe/blob/master/List2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Lists**
#
# Lists can be thought ofthe most general version of a sequence in python. Unlike strings, they are mutable, meaning the elements inside a list can be changed!
#
# We will learn about:
# 1. Creating lists
# 2. Indexing and Slicing Lists
# 3. Basic List Methods
# 4. Nesting Lists
# 5. Introduction to List comprehensions
#
# Lists are constructed with brackets [] and commas separating element in the list.

# %%
# my_list = ['abc', 'def']
# print(my_list)

# my_list = my_list.append(33)
# print(my_list)

my_list = [11, 7, 2,200,1, 'Abhi', 'Xerox', True, False]
# my_list.reverse()
# my_list.sort()
sorted_my_list = sorted(str(x) for x in my_list)
print(sorted_my_list)
print(my_list)
# Out:
# ['1', '11', '2', '200', '7', 'Abhi', 'False', 'True', 'Xerox']
# [11, 7, 2, 200, 1, 'Abhi', 'Xerox', True, False]

# %% [markdown]
# **Nesting Lists**
#
# A great feature of python data structures is that they support *nesting*. This means we can have data structures within data structures.
# For Example: A list iniside a list.
#
# We can use indexing to grab elements, but now there are two levels for the index. The items in the matrix object, and then the items inside that list.

# %%
list_1 = [1,2,3]
list_2 = [4,5,6]
list_3 = [7,8,9]

matrix = [list_1, list_2, list_3]
print(matrix)

matrix[0][1]
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
# 2

# %% [markdown]
# **List Comprehensions**
#
# Python has an advanced feature called list comprehensions. They allow for quick construction of lists. (For loops)
#
# We used a list comprehension below to grab the first element of every row in the matrix object.

# %%
first_col = [row[0] for row in matrix if row[0] > 1]
first_col
second_col = [row[1] for row in matrix]
second_col
# Out:
# [2, 5, 8]
